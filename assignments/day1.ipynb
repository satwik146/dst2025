# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_csv(r"C:\Users\mnsat\OneDrive\Desktop\dst2025aug\data\Orange_Telecom_Churn_Data.csv")
group_sizes = (data
.groupby('area_code')
.size())
print(group_sizes)
# Out:
# area_code
# 408    1259
# 415    2495
# 510    1246
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\mnsat\OneDrive\Desktop\dst2025aug\data\Orange_Telecom_Churn_Data.csv")

plt.plot(data.total_day_minutes, 
data.total_day_calls,
ls ='', marker='o')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\mnsat\OneDrive\Desktop\dst2025aug\data\Orange_Telecom_Churn_Data.csv")

#calls vs minutes of day and night
plt.plot(data.total_day_minutes, 
data.total_day_calls,
ls ='', marker='o',label = 'day' )
plt.plot(data.total_eve_minutes, 
data.total_eve_calls,
ls ='', marker='x', label = 'evening')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_csv(r"C:\Users\mnsat\OneDrive\Desktop\dst2025aug\data\Orange_Telecom_Churn_Data.csv")
sns.jointplot(x='total_day_minutes', 
y='total_day_calls', 
data=data, size=2)
